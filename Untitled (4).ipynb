# %%
import numpy as np
import pandas as pd

# %%
df1=pd.read_excel("FirstDecade.xlsx",index_col='Date',usecols=['Date','Open','High','Low','Close'])
df1
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-c46e5ae39d8e> in <cell line: 1>()
# ----> 1 df1=pd.read_excel("FirstDecade.xlsx",index_col='Date',usecols=['Date','Open','High','Low','Close'])
#       2 df1
#
# NameError: name 'pd' is not defined

# %%
df2=pd.read_excel("secondDecade.xlsx",index_col='Date',usecols=['Date','Open','High','Low','Close'])
df2
# Out:
#                    Open         High          Low        Close
# Date
# 2011-01-03   458.930670   462.843556   454.034643   455.411041
# 2011-01-04   457.711602   458.596430   447.565558   450.180725
# 2011-01-05   450.377174   458.497933   449.000775   455.764771
# 2011-01-06   459.323930   464.829525   453.464394   460.778961
# 2011-01-07   462.469711   466.736535   447.584960   449.354614
# ...                 ...          ...          ...          ...
# 2020-12-23  2750.536191  2791.611761  2740.398693  2781.809082
# 2020-12-24  2782.048726  2793.859855  2757.374613  2782.383545
# 2020-12-28  2783.004833  2820.972241  2775.353961  2801.558105
# 2020-12-29  2792.568581  2823.172072  2792.568581  2802.610352
# 2020-12-30  2806.339675  2819.059296  2775.353738  2782.335205
#
# [2462 rows x 4 columns]

# %%
TCS_FD=df1.to_numpy()
TCS_FD
# Out:
# array([[ 27.78542288,  28.70024427,  27.78542288,  28.48499298],
#        [ 28.52086876,  28.97827946,  27.89305089,  28.09933281],
#        [ 28.16211253,  28.16211253,  25.6329026 ,  26.16206551],
#        ...,
#        [448.78465434, 452.59927422, 448.33244741, 450.80993652],
#        [451.85220333, 456.96454332, 451.08537154, 454.97857666],
#        [453.22852089, 461.99816787, 453.22852089, 460.18914795]])

# %%
TCS_SD=df2.to_numpy()
TCS_SD
# Out:
# array([[ 458.9306703 ,  462.84355613,  454.03464251,  455.41104126],
#        [ 457.71160247,  458.59643028,  447.56555776,  450.1807251 ],
#        [ 450.37717366,  458.497933  ,  449.0007754 ,  455.76477051],
#        ...,
#        [2783.00483331, 2820.97224087, 2775.35396091, 2801.55810547],
#        [2792.56858098, 2823.17207228, 2792.56858098, 2802.61035156],
#        [2806.33967519, 2819.05929622, 2775.35373788, 2782.33520508]])

# %%
TCS_FD.shape
# Out:
# (2106, 4)

# %%
TCS_FD.ndim
# Out:
# 2

# %%
TCS_FD
# Out:
# array([[ 27.78542288,  28.70024427,  27.78542288,  28.48499298],
#        [ 28.52086876,  28.97827946,  27.89305089,  28.09933281],
#        [ 28.16211253,  28.16211253,  25.6329026 ,  26.16206551],
#        ...,
#        [448.78465434, 452.59927422, 448.33244741, 450.80993652],
#        [451.85220333, 456.96454332, 451.08537154, 454.97857666],
#        [453.22852089, 461.99816787, 453.22852089, 460.18914795]])

# %%
newTCS_SD=TCS_SD[:,1:]
newTCS_SD
# Out:
# array([[ 454.03464251,  455.41104126],
#        [ 447.56555776,  450.1807251 ],
#        [ 449.0007754 ,  455.76477051],
#        ...,
#        [2775.35396091, 2801.55810547],
#        [2792.56858098, 2802.61035156],
#        [2775.35373788, 2782.33520508]])

# %%
TCS_SD=TCS_SD[:,1:]
TCS_SD
# Out:
# array([[ 454.03464251,  455.41104126],
#        [ 447.56555776,  450.1807251 ],
#        [ 449.0007754 ,  455.76477051],
#        ...,
#        [2775.35396091, 2801.55810547],
#        [2792.56858098, 2802.61035156],
#        [2775.35373788, 2782.33520508]])

# %% [markdown]
# # New Section
